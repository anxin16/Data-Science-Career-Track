# %%
import numpy as np
import pandas as pd

# %%
rng = pd.date_range('3/6/2012 00:00', periods = 15, freq = 'D')
rng.tz

# %%
rng_tz = pd.date_range('3/6/2012 00:00', periods = 15, freq = 'D', tz = 'Europe/London')
rng_tz.tz
# Out:
# <DstTzInfo 'Europe/London' LMT-1 day, 23:59:00 STD>

# %%
from pytz import common_timezones, all_timezones
print(len(common_timezones))
print(len(all_timezones))
print(set(all_timezones) - set(common_timezones))
# Out:
# 439
# 592
# {'Asia/Tel_Aviv', 'Etc/GMT-5', 'US/Aleutian', 'Etc/GMT+6', 'Chile/Continental', 'Pacific/Yap', 'Etc/GMT-3', 'Etc/Universal', 'Asia/Dacca', 'Navajo', 'Etc/GMT+8', 'Mexico/BajaSur', 'Jamaica', 'Asia/Kashgar', 'Portugal', 'MET', 'Atlantic/Jan_Mayen', 'Antarctica/South_Pole', 'Asia/Rangoon', 'Etc/GMT-8', 'Canada/Yukon', 'Atlantic/Faeroe', 'Pacific/Ponape', 'Poland', 'Asia/Saigon', 'Australia/NSW', 'Hongkong', 'Pacific/Samoa', 'Etc/GMT-2', 'Etc/GMT-11', 'Etc/GMT+7', 'Etc/GMT+10', 'America/Catamarca', 'Asia/Ashkhabad', 'Etc/GMT-14', 'Australia/Victoria', 'GB-Eire', 'Canada/East-Saskatchewan', 'Etc/GMT-7', 'Etc/GMT-10', 'Etc/GMT+9', 'America/Jujuy', 'EET', 'MST', 'HST', 'Iceland', 'Etc/GMT+2', 'Iran', 'Etc/GMT-12', 'PST8PDT', 'Asia/Chongqing', 'Asia/Ujung_Pandang', 'Brazil/East', 'Asia/Thimbu', 'America/Santa_Isabel', 'Etc/GMT+1', 'Universal', 'ROK', 'Etc/GMT+3', 'Etc/Greenwich', 'Mexico/General', 'PRC', 'America/Ensenada', 'America/Shiprock', 'MST7MDT', 'Europe/Belfast', 'America/Knox_IN', 'Japan', 'America/Atka', 'Africa/Asmera', 'America/Rosario', 'Cuba', 'Brazil/Acre', 'NZ', 'Asia/Harbin', 'America/Coral_Harbour', 'US/Michigan', 'Etc/GMT0', 'NZ-CHAT', 'America/Louisville', 'Etc/GMT+11', 'Asia/Katmandu', 'America/Montreal', 'Kwajalein', 'Australia/Yancowinna', 'EST', 'CST6CDT', 'America/Indianapolis', 'Brazil/West', 'Australia/ACT', 'America/Buenos_Aires', 'America/Virgin', 'Australia/Canberra', 'W-SU', 'Asia/Istanbul', 'Canada/Saskatchewan', 'ROC', 'Etc/GMT-4', 'Chile/EasterIsland', 'US/Samoa', 'America/Cordoba', 'Australia/Tasmania', 'Etc/GMT', 'US/East-Indiana', 'America/Argentina/ComodRivadavia', 'Etc/GMT+12', 'EST5EDT', 'Pacific/Truk', 'GMT+0', 'Libya', 'Europe/Tiraspol', 'CET', 'UCT', 'US/Indiana-Starke', 'Asia/Chungking', 'Australia/West', 'Asia/Calcutta', 'Eire', 'Etc/GMT+4', 'Etc/GMT-0', 'Asia/Macao', 'Etc/GMT-13', 'Etc/GMT-9', 'WET', 'Etc/Zulu', 'Turkey', 'Singapore', 'Mexico/BajaNorte', 'Etc/GMT+5', 'Africa/Timbuktu', 'Australia/LHI', 'Australia/Queensland', 'Etc/GMT+0', 'GMT0', 'Zulu', 'Etc/UTC', 'GMT-0', 'America/Mendoza', 'GB', 'America/Porto_Acre', 'Australia/South', 'Etc/GMT-1', 'Israel', 'Egypt', 'Asia/Ulan_Bator', 'Etc/UCT', 'Greenwich', 'Brazil/DeNoronha', 'Etc/GMT-6', 'US/Pacific-New', 'America/Fort_Wayne', 'Australia/North', 'Europe/Nicosia'}

# %%
# You can also localize a naive timestamp
t_naive = pd.Timestamp('2016-07-10 08:50')
t_naive
# Out:
# Timestamp('2016-07-10 08:50:00')

# %%
t = t_naive.tz_localize(tz = 'US/Central')
t
# Out:
# Timestamp('2016-07-10 08:50:00-0500', tz='US/Central')

# %%
t.tz_convert('Asia/Tokyo')
# Out:
# Timestamp('2016-07-10 22:50:00+0900', tz='Asia/Tokyo')

# %%
# how to handle daylight savings?
rng = pd.date_range('2016-03-10', periods=10, tz='US/Central')
ts = pd.Series(range(10), index=rng)
ts
# Out:
# 2016-03-10 00:00:00-06:00    0
# 2016-03-11 00:00:00-06:00    1
# 2016-03-12 00:00:00-06:00    2
# 2016-03-13 00:00:00-06:00    3
# 2016-03-14 00:00:00-05:00    4
# 2016-03-15 00:00:00-05:00    5
# 2016-03-16 00:00:00-05:00    6
# 2016-03-17 00:00:00-05:00    7
# 2016-03-18 00:00:00-05:00    8
# 2016-03-19 00:00:00-05:00    9
# Freq: D, dtype: int64

# %%
rng = pd.date_range('2016-03-10', periods=10, tz='utc')
ts = pd.Series(range(10), index=rng)
ts
# Out:
# 2016-03-10 00:00:00+00:00    0
# 2016-03-11 00:00:00+00:00    1
# 2016-03-12 00:00:00+00:00    2
# 2016-03-13 00:00:00+00:00    3
# 2016-03-14 00:00:00+00:00    4
# 2016-03-15 00:00:00+00:00    5
# 2016-03-16 00:00:00+00:00    6
# 2016-03-17 00:00:00+00:00    7
# 2016-03-18 00:00:00+00:00    8
# 2016-03-19 00:00:00+00:00    9
# Freq: D, dtype: int64

# %%
ts.tz_convert('US/Central')
# Out:
# 2016-03-09 18:00:00-06:00    0
# 2016-03-10 18:00:00-06:00    1
# 2016-03-11 18:00:00-06:00    2
# 2016-03-12 18:00:00-06:00    3
# 2016-03-13 19:00:00-05:00    4
# 2016-03-14 19:00:00-05:00    5
# 2016-03-15 19:00:00-05:00    6
# 2016-03-16 19:00:00-05:00    7
# 2016-03-17 19:00:00-05:00    8
# 2016-03-18 19:00:00-05:00    9
# Freq: D, dtype: int64

# %%
pd.date_range('03-12-2016 22:00', periods = 12, freq = 'H', tz = 'US/Eastern')
# Out:
# DatetimeIndex(['2016-03-12 22:00:00-05:00', '2016-03-12 23:00:00-05:00',
#                '2016-03-13 00:00:00-05:00', '2016-03-13 01:00:00-05:00',
#                '2016-03-13 03:00:00-04:00', '2016-03-13 04:00:00-04:00',
#                '2016-03-13 05:00:00-04:00', '2016-03-13 06:00:00-04:00',
#                '2016-03-13 07:00:00-04:00', '2016-03-13 08:00:00-04:00',
#                '2016-03-13 09:00:00-04:00', '2016-03-13 10:00:00-04:00'],
#               dtype='datetime64[ns, US/Eastern]', freq='H')

# %%
# May autocorrect an error rather than giving you a non-existent time error
pd.Timestamp('2016-03-13 02:00', tz = 'US/Eastern')
# Out:
# Timestamp('2016-03-13 03:00:00-0400', tz='US/Eastern')
